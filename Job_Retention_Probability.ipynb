# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_data = pd.read_csv('aug_train.csv')

# %%
train_data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
train_data["gender"].fillna("No Data", inplace = True)
train_data["relevent_experience"].fillna("No Data", inplace = True)
train_data["enrolled_university"].fillna("No Data", inplace = True)
train_data["major_discipline"].fillna("No Data", inplace = True)
train_data["company_size"].fillna("No Data", inplace = True)
train_data["education_level"].fillna("education_level", inplace = True)
train_data["company_size"].fillna("company_size", inplace = True)
train_data["company_type"].fillna("company_type", inplace = True)
train_data["last_new_job"].fillna("last_new_job", inplace = True)
train_data["city"].fillna("city", inplace = True)
train_data["experience"].fillna("experience", inplace = True)

# %%
train_data
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  No Data
# 3            33241  city_115                   0.789  No Data
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  No Data
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(train_data['gender'])
train_data['gender'] = enc.transform(train_data['gender'])

# %%
enc.fit(train_data['relevent_experience'])
train_data['relevent_experience'] = enc.transform(train_data['relevent_experience'])

enc.fit(train_data['enrolled_university'])
train_data['enrolled_university'] = enc.transform(train_data['enrolled_university'])

enc.fit(train_data['major_discipline'])
train_data['major_discipline'] = enc.transform(train_data['major_discipline'])

enc.fit(train_data['company_size'])
train_data['company_size'] = enc.transform(train_data['company_size'])

enc.fit(train_data['education_level'])
train_data['education_level'] = enc.transform(train_data['education_level'])

enc.fit(train_data['company_size'])
train_data['company_size'] = enc.transform(train_data['company_size'])

enc.fit(train_data['company_type'])
train_data['company_type'] = enc.transform(train_data['company_type'])

enc.fit(train_data['last_new_job'])
train_data['last_new_job'] = enc.transform(train_data['last_new_job'])

enc.fit(train_data['city'])
train_data['city'] = enc.transform(train_data['city'])

enc.fit(train_data['experience'])
train_data['experience'] = enc.transform(train_data['experience'])

# %%
train_data
# Out:
#        enrollee_id  city  city_development_index  gender  relevent_experience  \
# 0             8949     5                   0.920       1                    0
# 1            29725    77                   0.776       1                    1
# 2            11561    64                   0.624       2                    1
# 3            33241    14                   0.789       2                    1
# 4              666    50                   0.767       1                    0
# ...            ...   ...                     ...     ...                  ...
# 19153         7386    55                   0.878       1                    1
# 19154        31398     5                   0.920       1                    0
# 19155        24576     5                   0.920       1                    0
# 19156         5756    94                   0.802       1                    0
# 19157        23834    95                   0.855       2                    1
#
# ...

# %%
from sklearn import preprocessing

df = train_data['training_hours']

normalized_dataset = (df - np.min(df)) / (np.max(df) - np.min(df))
print(normalized_dataset)


train_data['training_hours'] = normalized_dataset
# Out:
# 0        0.104478
# 1        0.137313
# 2        0.244776
# 3        0.152239
# 4        0.020896
#            ...
# 19153    0.122388
# 19154    0.152239
# 19155    0.128358
# 19156    0.286567
# 19157    0.376119
# Name: training_hours, Length: 19158, dtype: float64

# %%
train_data
# Out:
#        enrollee_id  city  city_development_index  gender  relevent_experience  \
# 0             8949     5                   0.920       1                    0
# 1            29725    77                   0.776       1                    1
# 2            11561    64                   0.624       2                    1
# 3            33241    14                   0.789       2                    1
# 4              666    50                   0.767       1                    0
# ...            ...   ...                     ...     ...                  ...
# 19153         7386    55                   0.878       1                    1
# 19154        31398     5                   0.920       1                    0
# 19155        24576     5                   0.920       1                    0
# 19156         5756    94                   0.802       1                    0
# 19157        23834    95                   0.855       2                    1
#
# ...

# %% [markdown]
# from sklearn.neighbors import KNeighborsClassifier
#
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(scaled_features,df['TARGET CLASS'],
#                                                     test_size=0.30)

# %%
from sklearn.model_selection import train_test_split
train_features, valid_features, train_labels, valid_labels=train_test_split(
    train_data.drop(labels=['enrollee_id','target'], axis=1),
    train_data['target'],
    test_size=0.2,
    random_state=41)

# %%
train_features
# Out:
#        city  city_development_index  gender  relevent_experience  \
# 7207      5                   0.920       1                    1
# 14408    48                   0.910       1                    0
# 2262     13                   0.926       1                    0
# 16483   103                   0.939       1                    0
# 1005     31                   0.836       2                    0
# ...     ...                     ...     ...                  ...
# 15829     5                   0.920       0                    1
# 18009   114                   0.925       1                    1
# 8513     30                   0.897       1                    0
# 931       5                   0.920       1                    0
# 1984      5                   0.920       1                    0
#
#        enrolled_university  education_level  major_discipline  experience  \
# 7207                     0                1                 3          17
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_features,train_labels)
    pred_i = knn.predict(valid_features)
    error_rate.append(np.mean(pred_i != valid_labels))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
test_data = pd.read_csv('aug_test.csv')
test_data
test_backup =  test_data

# %%
test_data["gender"].fillna("No Data", inplace = True)
test_data["relevent_experience"].fillna("No Data", inplace = True)
test_data["enrolled_university"].fillna("No Data", inplace = True)
test_data["major_discipline"].fillna("No Data", inplace = True)
test_data["company_size"].fillna("No Data", inplace = True)
test_data["education_level"].fillna("education_level", inplace = True)
test_data["company_size"].fillna("company_size", inplace = True)
test_data["company_type"].fillna("company_type", inplace = True)
test_data["last_new_job"].fillna("last_new_job", inplace = True)
test_data["city"].fillna("city", inplace = True)
test_data["experience"].fillna("experience", inplace = True)

# %%
test_data
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
enc.fit(test_data['gender'])
test_data['gender'] = enc.transform(test_data['gender'])

enc.fit(test_data['relevent_experience'])
test_data['relevent_experience'] = enc.transform(test_data['relevent_experience'])

enc.fit(test_data['enrolled_university'])
test_data['enrolled_university'] = enc.transform(test_data['enrolled_university'])

enc.fit(test_data['major_discipline'])
test_data['major_discipline'] = enc.transform(test_data['major_discipline'])

enc.fit(test_data['company_size'])
test_data['company_size'] = enc.transform(test_data['company_size'])

enc.fit(test_data['education_level'])
test_data['education_level'] = enc.transform(test_data['education_level'])

enc.fit(test_data['company_size'])
test_data['company_size'] = enc.transform(test_data['company_size'])

enc.fit(test_data['company_type'])
test_data['company_type'] = enc.transform(test_data['company_type'])

enc.fit(test_data['last_new_job'])
test_data['last_new_job'] = enc.transform(test_data['last_new_job'])

enc.fit(test_data['city'])
test_data['city'] = enc.transform(test_data['city'])

enc.fit(test_data['experience'])
test_data['experience'] = enc.transform(test_data['experience'])

# %%
from sklearn import preprocessing

df = test_data['training_hours']

normalized_dataset = (df - np.min(df)) / (np.max(df) - np.min(df))
print(normalized_dataset)


test_data['training_hours'] = normalized_dataset
# Out:
# 0       0.060060
# 1       0.291291
# 2       0.042042
# 3       0.114114
# 4       0.213213
#           ...
# 2124    0.042042
# 2125    0.087087
# 2126    0.051051
# 2127    0.249249
# 2128    0.030030
# Name: training_hours, Length: 2129, dtype: float64

# %%
test = test_data.drop(['enrollee_id'], axis=1)
test
# Out:
#       city  city_development_index  gender  relevent_experience  \
# 0       69                   0.827       1                    0
# 1        5                   0.920       0                    0
# 2       55                   0.624       1                    1
# 3       22                   0.827       1                    0
# 4        5                   0.920       1                    0
# ...    ...                     ...     ...                  ...
# 2124     5                   0.920       1                    1
# 2125    25                   0.897       1                    0
# 2126     2                   0.887       1                    1
# 2127     4                   0.804       1                    0
# 2128     4                   0.804       1                    0
#
#       enrolled_university  education_level  major_discipline  experience  \
# 0                       0                0                 6          19
# ...

# %%
knn = KNeighborsClassifier(n_neighbors=16)
knn.fit(train_features,train_labels)

pred = knn.predict(test)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
result = test_backup
result['result'] = pred

# %%
result
# Out:
#       enrollee_id  city  city_development_index  gender  relevent_experience  \
# 0           32403    69                   0.827       1                    0
# 1            9858     5                   0.920       0                    0
# 2           31806    55                   0.624       1                    1
# 3           27385    22                   0.827       1                    0
# 4           27724     5                   0.920       1                    0
# ...           ...   ...                     ...     ...                  ...
# 2124         1289     5                   0.920       1                    1
# 2125          195    25                   0.897       1                    0
# 2126        31762     2                   0.887       1                    1
# 2127         7873     4                   0.804       1                    0
# 2128        12215     4                   0.804       1                    0
#
# ...

# %%
result[result['result']==1]
# Out:
#       enrollee_id  city  city_development_index  gender  relevent_experience  \
# 20          15359     5                   0.920       2                    1
# 23           5058     5                   0.920       1                    1
# 31           7683     5                   0.920       1                    0
# 44          18133     5                   0.920       1                    1
# 46           6312    42                   0.920       1                    0
# ...           ...   ...                     ...     ...                  ...
# 2047        13292     5                   0.920       0                    0
# 2049           37     5                   0.920       1                    1
# 2088         5280    24                   0.698       1                    0
# 2102        23606     5                   0.920       2                    1
# 2112        28552    24                   0.698       1                    0
#
# ...

# %%
result.to_csv('result.csv')
